# %%
import pandas as pd
a=pd.Series([10,20,30,40,50])
print(a)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
s=pd.Series([1,3,4,5,6,8,9,3,5,4])
s.describe()
# Out:
# count    10.000000
# mean      4.800000
# std       2.394438
# min       1.000000
# 25%       3.250000
# 50%       4.500000
# 75%       5.750000
# max       9.000000
# dtype: float64

# %%
dropped =s.drop(5)
dropped
# Out:
# 0    1
# 1    3
# 2    4
# 3    5
# 4    6
# 6    9
# 7    3
# 8    5
# 9    4
# dtype: int64

# %%
p=pd.Series([2,4,67,None,54,76,6])
p.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# dtype: bool

# %%
p.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# dtype: bool

# %%
import numpy as np
p=pd.Series([3,5,7,np.nan,4,None])
p.fillna
# Out:
# <bound method NDFrame.fillna of 0    3.0
# 1    5.0
# 2    7.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64>

# %%
filled=p.fillna(800)
filled
# Out:
# 0      3.0
# 1      5.0
# 2      7.0
# 3    800.0
# 4      4.0
# 5    800.0
# dtype: float64

# %%
p.dropna()
# Out:
# 0    3.0
# 1    5.0
# 2    7.0
# 4    4.0
# dtype: float64

# %%
p.iloc[1]
# Out:
# 5.0

# %%
data={
    'Name':['Akhila','Anusha','Shiva','Sai','Pooja','Harsha'],
    'Role':['Founder','Designer','Growth Manager','Course Designer','Manager','Developer'],
    'Email':['akhi@gmail.com','anu455@gmail.com','shiva@gmail.com','sai@gmail.com','pooja123@gmail.com','harsha@gmail.com']
}
teamx=pd.DataFrame(data)

# %%
teamx.head(6)
# Out:
#      Name             Role               Email
# 0  Akhila          Founder      akhi@gmail.com
# 1  Anusha         Designer    anu455@gmail.com
# 2   Shiva   Growth Manager     shiva@gmail.com
# 3     Sai  Course Designer       sai@gmail.com
# 4   Pooja          Manager  pooja123@gmail.com
# 5  Harsha        Developer    harsha@gmail.com

# %%
teamx.tail(6)
# Out:
#      Name             Role               Email
# 0  Akhila          Founder      akhi@gmail.com
# 1  Anusha         Designer    anu455@gmail.com
# 2   Shiva   Growth Manager     shiva@gmail.com
# 3     Sai  Course Designer       sai@gmail.com
# 4   Pooja          Manager  pooja123@gmail.com
# 5  Harsha        Developer    harsha@gmail.com

# %%
teamx.head(4)
# Out:
#      Name             Role             Email
# 0  Akhila          Founder    akhi@gmail.com
# 1  Anusha         Designer  anu455@gmail.com
# 2   Shiva   Growth Manager   shiva@gmail.com
# 3     Sai  Course Designer     sai@gmail.com

# %%
teamx.tail(4)
# Out:
#      Name             Role               Email
# 2   Shiva   Growth Manager     shiva@gmail.com
# 3     Sai  Course Designer       sai@gmail.com
# 4   Pooja          Manager  pooja123@gmail.com
# 5  Harsha        Developer    harsha@gmail.com

# %%
import pandas as pd
df=pd.read_csv('countries.csv')
df.head()
# Out:
#   Country Name ISO Code  Dialing Code  Region           Capital  Population
# 0  Afghanistan       AF            93    Asia             Kabul    41128771
# 1      Albania       AL           355  Europe            Tirana     2811666
# 2      Algeria       DZ           213  Africa           Algiers    45606480
# 3      Andorra       AD           376  Europe  Andorra la Vella       79824
# 4       Angola       AO           244  Africa            Luanda    35588987

# %%
df.head(6)
# Out:
#           Country Name ISO Code  Dialing Code         Region  \
# 0          Afghanistan       AF            93           Asia
# 1              Albania       AL           355         Europe
# 2              Algeria       DZ           213         Africa
# 3              Andorra       AD           376         Europe
# 4               Angola       AO           244         Africa
# 5  Antigua and Barbuda       AG          -267  North America
#
#             Capital  Population
# 0             Kabul    41128771
# 1            Tirana     2811666
# 2           Algiers    45606480
# 3  Andorra la Vella       79824
# 4            Luanda    35588987
# 5      Saint John's       93219

# %%
df.shape
# Out:
# (196, 6)

# %%
df.columns
# Out:
# Index(['Country Name', 'ISO Code', 'Dialing Code', 'Region', 'Capital',
#        'Population'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country Name    object
# ISO Code        object
# Dialing Code     int64
# Region          object
# Capital         object
# Population       int64
# dtype: object
